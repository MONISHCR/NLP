# %%
import pandas as pd
import numpy as np

# %%
import spacy

# %%
import nltk

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install wikipedia
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11695 sha256=ed4abb75501b5e12f0c1d0b31da769c063bfd7b61b3b5695b31bc104665dfe9a
#   Stored in directory: /root/.cache/pip/wheels/c2/46/f4/caa1bee71096d7b0cdca2f2a2af45cacf35c5760bee8f00948
# Successfully built wikipedia
# ...

# %%
import wikipedia
text=wikipedia.page("Natural language processing").content

# %%
from nltk.corpus import stopwords
stopwords_english=stopwords.words('english')

# %%
word_tokens=word_tokenize(text)
print(word_tokens)
# Out:
# ['Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'an', 'interdisciplinary', 'subfield', 'of', 'linguistics', ',', 'computer', 'science', ',', 'and', 'artificial', 'intelligence', 'concerned', 'with', 'the', 'interactions', 'between', 'computers', 'and', 'human', 'language', ',', 'in', 'particular', 'how', 'to', 'program', 'computers', 'to', 'process', 'and', 'analyze', 'large', 'amounts', 'of', 'natural', 'language', 'data', '.', 'The', 'goal', 'is', 'a', 'computer', 'capable', 'of', '``', 'understanding', "''", 'the', 'contents', 'of', 'documents', ',', 'including', 'the', 'contextual', 'nuances', 'of', 'the', 'language', 'within', 'them', '.', 'The', 'technology', 'can', 'then', 'accurately', 'extract', 'information', 'and', 'insights', 'contained', 'in', 'the', 'documents', 'as', 'well', 'as', 'categorize', 'and', 'organize', 'the', 'documents', 'themselves', '.', 'Challenges', 'in', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recognition',
# ...

# %%
len(word_tokens)
# Out:
# 5611

# %%
sent_tokens=sent_tokenize(text)
lists=[]
for sent in sent_tokens:
   lists.append(word_tokenize(sent))
print(lists)
# Out:
# [['Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'an', 'interdisciplinary', 'subfield', 'of', 'linguistics', ',', 'computer', 'science', ',', 'and', 'artificial', 'intelligence', 'concerned', 'with', 'the', 'interactions', 'between', 'computers', 'and', 'human', 'language', ',', 'in', 'particular', 'how', 'to', 'program', 'computers', 'to', 'process', 'and', 'analyze', 'large', 'amounts', 'of', 'natural', 'language', 'data', '.'], ['The', 'goal', 'is', 'a', 'computer', 'capable', 'of', '``', 'understanding', "''", 'the', 'contents', 'of', 'documents', ',', 'including', 'the', 'contextual', 'nuances', 'of', 'the', 'language', 'within', 'them', '.'], ['The', 'technology', 'can', 'then', 'accurately', 'extract', 'information', 'and', 'insights', 'contained', 'in', 'the', 'documents', 'as', 'well', 'as', 'categorize', 'and', 'organize', 'the', 'documents', 'themselves', '.'], ['Challenges', 'in', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recogn
# ...

# %%
sum=0
for i in lists:
   sum=sum+len(i)
   #print(len(i))
print(sum)
# Out:
# 5612

# %%
word_tokens_sp=[x for x in word_tokens if x not in stopwords_english]

# %%
stp_words = [x for x in word_tokens if x in stopwords_english]

# %%
len(stp_words)
# Out:
# 1640

# %%
print(word_tokens_sp)
# Out:
# ['Natural', 'language', 'processing', '(', 'NLP', ')', 'interdisciplinary', 'subfield', 'linguistics', ',', 'computer', 'science', ',', 'artificial', 'intelligence', 'concerned', 'interactions', 'computers', 'human', 'language', ',', 'particular', 'program', 'computers', 'process', 'analyze', 'large', 'amounts', 'natural', 'language', 'data', '.', 'The', 'goal', 'computer', 'capable', '``', 'understanding', "''", 'contents', 'documents', ',', 'including', 'contextual', 'nuances', 'language', 'within', '.', 'The', 'technology', 'accurately', 'extract', 'information', 'insights', 'contained', 'documents', 'well', 'categorize', 'organize', 'documents', '.', 'Challenges', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recognition', ',', 'natural-language', 'understanding', ',', 'natural-language', 'generation', '.', '==', 'History', '==', 'Natural', 'language', 'processing', 'roots', '1950s', '.', 'Already', '1950', ',', 'Alan', 'Turing', 'published', 'article',
# ...

# %%
len(word_tokens_sp)
# Out:
# 3971

# %%
percent = ((len(stp_words)/len(word_tokens))*100)

# %%
print(str(percent)+'%')
# Out:
# 29.228301550525753%

# %% [markdown]
# **lab Experiment - 2B**

# %% [markdown]
# **Using NLTK**

# %%
from nltk.stem import PorterStemmer

# %%
from tqdm import tqdm

# %%
stem_list = []

# %%
stemmer = PorterStemmer()
for word in tqdm(word_tokens_sp):
  stem_word = stemmer.stem(word)
  stem_list.append(stem_word)
# Out:
# 100%|██████████| 3971/3971 [00:00<00:00, 65754.63it/s]

# %%
print(stem_list)
# Out:
# ['natur', 'languag', 'process', '(', 'nlp', ')', 'interdisciplinari', 'subfield', 'linguist', ',', 'comput', 'scienc', ',', 'artifici', 'intellig', 'concern', 'interact', 'comput', 'human', 'languag', ',', 'particular', 'program', 'comput', 'process', 'analyz', 'larg', 'amount', 'natur', 'languag', 'data', '.', 'the', 'goal', 'comput', 'capabl', '``', 'understand', "''", 'content', 'document', ',', 'includ', 'contextu', 'nuanc', 'languag', 'within', '.', 'the', 'technolog', 'accur', 'extract', 'inform', 'insight', 'contain', 'document', 'well', 'categor', 'organ', 'document', '.', 'challeng', 'natur', 'languag', 'process', 'frequent', 'involv', 'speech', 'recognit', ',', 'natural-languag', 'understand', ',', 'natural-languag', 'gener', '.', '==', 'histori', '==', 'natur', 'languag', 'process', 'root', '1950', '.', 'alreadi', '1950', ',', 'alan', 'ture', 'publish', 'articl', 'titl', '``', 'comput', 'machineri', 'intellig', "''", 'propos', 'call', 'ture', 'test', 'criterion', 'intellig
# ...

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemma_list = []

# %%
lemmatizer = WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
for word in tqdm(word_tokens_sp):
  lemma_word = lemmatizer.lemmatize(word)
  #print(word,"----->>>>",lemma_word)
  lemma_list.append(lemma_word)
# Out:
# 100%|██████████| 3971/3971 [00:00<00:00, 218425.26it/s]

# %%
print(lemma_list)
# Out:
# ['Natural', 'language', 'processing', '(', 'NLP', ')', 'interdisciplinary', 'subfield', 'linguistics', ',', 'computer', 'science', ',', 'artificial', 'intelligence', 'concerned', 'interaction', 'computer', 'human', 'language', ',', 'particular', 'program', 'computer', 'process', 'analyze', 'large', 'amount', 'natural', 'language', 'data', '.', 'The', 'goal', 'computer', 'capable', '``', 'understanding', "''", 'content', 'document', ',', 'including', 'contextual', 'nuance', 'language', 'within', '.', 'The', 'technology', 'accurately', 'extract', 'information', 'insight', 'contained', 'document', 'well', 'categorize', 'organize', 'document', '.', 'Challenges', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recognition', ',', 'natural-language', 'understanding', ',', 'natural-language', 'generation', '.', '==', 'History', '==', 'Natural', 'language', 'processing', 'root', '1950s', '.', 'Already', '1950', ',', 'Alan', 'Turing', 'published', 'article', 'titled', 
# ...

# %% [markdown]
# **Using Spacy**

# %%
sp = spacy.load("en_core_web_sm")

# %%
sp = sp(text)

# %% [markdown]
# **Spacy doesnot provide Stemming tools**

# %%
#Lemmatization
splemma = []
for word in tqdm(sp):
  #print(word.text,"--> ",word.lemma_)
  splemma.append(word.lemma_)
# Out:
# 100%|██████████| 6076/6076 [00:00<00:00, 807496.55it/s]
